# %% [markdown]
# # Tutorial: Fetch Basic Stock Information with Python
# *Learn how to retrieve basic stock data, including company profile, key officers, earnings call transcripts and news step by step using Python.*

# %% [markdown]
# ## Step 1: Install and Import Required Packages, Initialize Ticker
# *In this step, you’ll set up your Python environment and initialize a stock ticker object for fetching data.*

# %%
from defeatbeta_api.data.ticker import Ticker

# %%
ticker = Ticker("BABA")

# %% [markdown]
# ## Step 2: Fetching Basic Stock Information
#
# You can fetch company profile, key officers, stock calendar, and news by following the examples in the official documentation. Click the link below to see all code examples and copy them directly:
#
# [View Examples on GitHub](https://github.com/defeat-beta/defeatbeta-api/blob/main/doc/Info_Examples.md)
#
# > **Tip**: After copying the methods, you can execute them directly with your `Ticker` object.
