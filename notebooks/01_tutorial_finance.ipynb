# %% [markdown]
# # Tutorial: Fetch Stock Financial Information with Python
# *Learn how to retrieve basic stock data, including price, statement, earning calendar, earnings report, splits, dividends, revenue forecast, earnings forecast, summary, revenue breakdown, geography breakdown and product breakdown step by step using Python.*

# %% [markdown]
# ## Step 1: Install and Import Required Packages, Initialize Ticker
# *In this step, you’ll set up your Python environment and initialize a stock ticker object for fetching data.*

# %%
from defeatbeta_api.data.ticker import Ticker

# %%
ticker = Ticker("BABA")

# %% [markdown]
# ## Step 2: Fetching Financial Information
#
# You can fetch quarterly and annual financial data, including balance sheets, income statements, cash flow statements, splits, dividends, and forecasts by following the examples in the official documentation. Click the link below to see all code examples and copy them directly:
#
# [View Financial Examples on GitHub](https://github.com/defeat-beta/defeatbeta-api/blob/main/doc/api/Finance_Examples.md)
#
# > **Tip**: After copying the methods, you can execute them directly with your `Ticker` object.
