# %% [markdown]
# # Tutorial: Fetch Stock Value & Valuation Metrics with Python
#
# *Learn how to retrieve stock valuation and value metrics, including P/E, PEG, price-to-book, dividend yield, and other value indicators step by step using Python.*

# %% [markdown]
# ## Step 1: Install and Import Required Packages, Initialize Ticker
# *In this step, you’ll set up your Python environment and initialize a stock ticker object for fetching data.*

# %%
from defeatbeta_api.data.ticker import Ticker

# %%
ticker = Ticker("BABA")

# %% [markdown]
# ## Step 2: Fetching Value / Valuation Metrics
#
# You can fetch valuation-related metrics by following the examples in the official documentation. Click the link below to see all code examples and copy them directly:
#
# [View Value Examples on GitHub](https://github.com/defeat-beta/defeatbeta-api/blob/main/doc/Value_Examples.md)
#
# > **Tip**: After copying the methods, you can execute them directly with your `Ticker` object.
