# %% [markdown]
# # Tutorial: Fetch Stock Growth Metrics with Python
#
# *Learn how to retrieve stock growth-related data (e.g. revenue growth, earnings growth, other growth indicators) step by step using Python.*

# %% [markdown]
# ## Step 1: Install and Import Required Packages, Initialize Ticker
# *In this step, you’ll set up your Python environment and initialize a stock ticker object for fetching data.*

# %%
from defeatbeta_api.data.ticker import Ticker

# %%
ticker = Ticker("BABA")

# %% [markdown]
# ## Step 2: Fetch Growth‑related Metrics
#
# You can fetch growth metrics by following the examples in the official documentation. Click the link below to see all code examples and copy them directly:
#
# [View Growth Examples on GitHub](https://github.com/defeat-beta/defeatbeta-api/blob/main/doc/Growth_Examples.md)
#
# > **Tip**: After copying the methods, you can execute them directly with your `Ticker` object.
