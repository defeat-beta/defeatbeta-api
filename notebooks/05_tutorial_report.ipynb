# %% [markdown]
# # Tutorial: Generate Analysis Report with Python
#
# `defeatbeta-api` provides easy-to-use stock data analysis and report generation features. Using the `tearsheet` module, you can quickly generate HTML reports for a stock and view them directly in a web browser.

# %% [markdown]
# ## Step 1: Install and Import Required Packages, Initialize Ticker
# *In this step, you’ll set up your Python environment and initialize a stock ticker object for fetching data.*

# %%
from defeatbeta_api.data.ticker import Ticker
# Out:
# [nltk_data] Downloading package punkt_tab to /tmp/nltk...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ______      __           _    ______      _
# |  _  \    / _|         | |   | ___ \    | |
# | | | |___| |_ ___  __ _| |_  | |_/ / ___| |_ __ _
# | | | / _ \  _/ _ \/ _` | __| | ___ \/ _ \ __/ _` |
# | |/ /  __/ ||  __/ (_| | |_  | |_/ /  __/ || (_| |
# |___/ \___|_| \___|\__,_|\__| \____/ \___|\__\__,_|
# 📈:: Data Update Time ::	2025-11-28 ::
# 📈:: Software Version ::	0.0.27      ::

# %%
ticker = Ticker("BABA")

# %% [markdown]
# ## Step 2: Generate Report
#
# Here is a simple example showing how to generate a stock report for Alibaba (BABA):

# %%
import defeatbeta_api.reports.tearsheet as tearsheet
# Out:
# 2025-12-02 11:18:05 INFO matplotlib.font_manager MainThread - generated new fontManager

# %%
tearsheet.html(ticker)
# Out:
# <script> var bl=new Blob(['<!-- generated by DefeatBeta API for Python --><!DOCTYPE html><html lang="en"><head> <meta charset="utf-8"> <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"> <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"> <title>BABA Value Analysis Tearsheet</title> <meta name="robots" content="noindex, nofollow"> <link rel="shortcut icon" href="https://github.com/defeat-beta/defeatbeta-api/blob/main/doc/favicon.ico?raw=true" type="image/x-icon"> <style> body { -webkit-font-smoothing: antialiased; -moz-osx-font-smoothing: grayscale; margin: 30px } body, p, table, td, th { font-family: Arial, "DejaVu Sans", sans-serif; font-size: 13px; line-height: 1.4; } .container { max-width: 960px; margin: auto } img, svg { width: 100% } h1, h2, h3, h4 { font-weight: 400; margin: 0 } h1 dt { display: inline; margin-left: 10px; font-size: 14px } h3 { margin-bottom: 10px; font-weight: 700 } h4 { color: grey } h4 a { color: #09c; text-dec
# ...
